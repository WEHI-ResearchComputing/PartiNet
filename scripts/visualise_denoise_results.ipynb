# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
from PIL import Image
import glob
import os

# %%
from topaz.utils.data.loader import load_image
import topaz.mrc as mrc

# %%
##Set Paths and filenames
name = 'stack_0289_2x_dfpt'
raw_path='/vast/scratch/users/iskander.j/PartiNet_data/10059/micrographs/'
denoised_path='/vast/scratch/users/iskander.j/PartiNet_data/10059/denoised_micrographs/jpg/'

# %%
# load the raw micrograph
mic_raw = np.array(load_image( os.path.join(raw_path,name + '.mrc')), copy=False)
# load the denoised micrograph
mic_dn = np.array(load_image( os.path.join(denoised_path, name + '.jpg')), copy=False)

# scale them for visualization
mu = mic_dn.mean()
std = mic_dn.std()

mic_raw = (mic_raw - mu)/std
mic_dn = (mic_dn - mu)/std

_,ax = plt.subplots(1,2,figsize=(24,12))

ax[0].imshow(mic_raw, vmin=-4, vmax=4, cmap='Greys_r')
ax[1].imshow(mic_dn, vmin=-4, vmax=4, cmap='Greys_r')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-bce002e0f8f0> in <module>
#       1 # load the raw micrograph
# ----> 2 mic_raw = np.array(load_image( os.path.join(raw_path,name + '.mrc')), copy=False)
#       3 # load the denoised micrograph
#       4 mic_dn = np.array(load_image( os.path.join(denoised_path, name + '.jpg')), copy=False)
#       5
#
# /vast/projects/miti2324/envs/topaz_env/lib/python3.6/site-packages/topaz/utils/data/loader.py in load_image(path, standardize)
#     103     ext = os.path.splitext(path)[1]
#     104     if ext == '.mrc':
# --> 105         image = load_mrc(path, standardize=standardize)
#     106     else:
#     107         image = load_pil(path, standardize=standardize)
#
# /vast/projects/miti2324/envs/topaz_env/lib/python3.6/site-packages/topaz/utils/data/loader.py in load_mrc(path, standardize)
#      49     with open(path, 'rb') as f:
#      50         content = f.read()
# ---> 51     image, header, extended_header = mrc.parse(content)
#      52     if image.dtype == np.float16:
#      53         image = image.astype(np.float32)
#
# /vast/projects/miti2324/envs/topaz_env/lib/python3.6/site-packages/topaz/mrc.py in parse(content)
#     140     array = array[:header.nz*header.ny*header.nx]
#     141     ## reshape the array
# --> 142     array = np.reshape(array, (header.nz, header.ny, header.nx)) # , order='F')
#     143     if header.nz == 1:
#     144         array = array[0]
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# /vast/projects/miti2324/envs/topaz_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# /vast/projects/miti2324/envs/topaz_env/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 6946528 into shape (1,3710,3838)

# %%
## look at a detail of the micrograph
crop = (2000,3000,3500,4500)
crop=(2000,3000,0,2000)
_,ax = plt.subplots(1,2,figsize=(24,12))

ax[0].imshow(mic_raw[crop[0]:crop[1],crop[2]:crop[3]], vmin=-4, vmax=4, cmap='Greys_r')
ax[1].imshow(mic_dn[crop[0]:crop[1],crop[2]:crop[3]], vmin=-4, vmax=4, cmap='Greys_r')
